# %% [markdown]
# # Libraries

# %%
# Exemplos de algumas bibliotecas bem conhecidas
- Consumo de APIs = Request
- Tratamento e análise de dados = Pandas
- Cálculos matemáticos = Numpy
- Gráficos e visualização de dados = Matplotlib
- Desenvolvimento Web = Flask
- Criação de Dashboards = Streamlit
- Criação de Jogos = Pygame
- Inteligência artificial = Scikit-Learn
- Web Scrapping = Beautifulsoup4
- Visão Computacional = Opencv-Python
